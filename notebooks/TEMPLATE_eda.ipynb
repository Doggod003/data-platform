# %% [markdown]
# # EDA Template
#
# Date: | Question: | Data source:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import your own package — promoted logic lives in src/
from data_platform.config import settings

pd.set_option('display.max_columns', None)
sns.set_theme()

# %%
# Load
df = pd.DataFrame()  # pd.read_csv('../data/raw/file.csv')
df.head()

# %%
# Profile
# df.info()
# df.describe()
# df.isna().mean().sort_values(ascending=False)

# %% [markdown]
# ## Findings
#
# -
#
# ## Next steps / what to promote to src
#
# -
